# %% [markdown]
# ## Analysis of health status for US population

# %% [markdown]
# * Dependences

# %%
import os
import csv
# %matplotlib inline

import matplotlib.pyplot as plt


import collections
import pandas as pd
import numpy as np
import requests
import time
import datetime

# %% [markdown]
# * Loaded file
# * Readed  file and stored into Pandas data frame

# %%
file_to_load = "Sacramento_Crime_Data_From_Current_Year.csv"

Sac_crime_df = pd.read_csv(file_to_load, delimiter=',', encoding="utf-8", dtype={'Time Occurred':str})
Sac_crime_df.head()
# Out:
#    OBJECTID  Record_ID  Offense_Code Offense_Ext Offense_Category  \
# 0      1001    1432285          5400           1          TRAFFIC
# 1      1002    1432286          2399           2          LARCENY
# 2      1003    1432287          2202           0         BURGLARY
# 3      1004    1432290          2399           2          LARCENY
# 4      1005    1432293          2299          01         BURGLARY
#
#                    Description Police_District Beat  Grid  \
# 0  TRAFFIC ACCIDENT-NON-INJURY               4   4A  0905
# 1           484 PC PETTY THEFT               6   6C  1111
# 2  459 PC BURG RESIDENCE-FORCE               5   5A  1501
# 3           484 PC PETTY THEFT               2   2C  0619
# 4          459 PC BURG VEHICLE               3   3M  0742
#
#              Occurence_Date
# 0  2020-01-10T00:20:05.000Z
# 1  2020-01-12T00:22:00.000Z
# 2  2020-01-10T00:09:30.000Z
# 3  2020-01-09T00:16:45.000Z
# 4  2020-01-13T00:21:00.000Z

# %%
# #Shrink data frame
# accident_df = collision_df.loc[:, ["Victim Descent", "Victim Age", 
#                                     "Date Occurred", "Time Occurred"]]
# # Reset index after shrunken dataframe and dropna applied
# accident_df.reset_index(drop=True, inplace=True)

# # # format age column
# accident_df['Victim Age'] = accident_df['Victim Age'].apply(np.int64)

# # format date column
Sac_crime_df['Occurence_Date'] = Sac_crime_df['Occurence_Date'].str[:10]
Sac_crime_df.loc[:,'Occurence_Date'] = Sac_crime_df['Occurence_Date'].astype("datetime64[ns]")
Sac_crime_df['Day of Week'] = Sac_crime_df['Occurence_Date'].dt.weekday_name

# # format time column
# Sac_crime_df['Hour'] = Sac_crime_df['Occurence_Date'].str[:2]

Sac_crime_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-63f6a2dbdeb6> in <module>
#      14
#      15 # # format time column
# ---> 16 Sac_crime_df['Hour'] = Sac_crime_df['Occurence_Date'].str[:2]
#      17
#      18 Sac_crime_df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# ...

# %%
Sac_crime_df['Occurence_Date'] = Sac_crime_df['Occurence_Date'].str[:10]
# Sac_crime_df.loc[:,"Occurence_Date"] = Sac_crime_df["Occurence_Date"].astype("datetime64[ns]")
# accident_df['Day of Week'] = accident_df['Date Occurred'].dt.weekday_name

# # format time column
Sac_crime_df['Hour'] = Sac_crime_df['Occurence_Date'].str[:2]

Sac_crime_df.head(20)
# Out:
#     OBJECTID  Record_ID  Offense_Code Offense_Ext Offense_Category  \
# 0       1001    1432285          5400           1          TRAFFIC
# 1       1002    1432286          2399           2          LARCENY
# 2       1003    1432287          2202           0         BURGLARY
# 3       1004    1432290          2399           2          LARCENY
# 4       1005    1432293          2299          01         BURGLARY
# 5       1006    1432294          2399           2          LARCENY
# 6       1007    1432296          1313          19          BATTERY
# 7       1008    1432297          1313          19          BATTERY
# 8       1009    1432299          5005           2   OBST JUDICIARY
# 9       1010    1432307          1299           0          ROBBERY
# 10      1011    1432309          2299          01         BURGLARY
# 11      1012    1432310          2399          23          LARCENY
# 12      1013    1432311          2303           1          LARCENY
# ...

# %%
month_list=[]
year_list=[]
for a in Sac_crime_df['Occurence_Date']:
    a.split('-')
    year,month,date=a.split('-')
    month_list.append(month)
    year_list.append(year)

# %%
month_list

# %%
month_list=[]
year_list=[]
for a in Sac_crime_df['Occurence_Date']:
    a.split('-')
    year,month,date=a.split('-')
    month_list.append(month)
    year_list.append(year)

January=[]
February=[]
March=[]
April=[]
May=[]
June=[]
July=[]
August=[]
September=[]
October=[]
November=[]
December=[]

for i in month_list:
    if (i=='01'):
        January.append(i)
    elif (i=='02'):
        February.append(i)   
    elif (i=='03'):
        March.append(i)
    elif (i=='04'):
        April.append(i)
    elif (i=='05'):
        May.append(i)
    elif (i=='06'):
        June.append(i)
    elif (i=='07'):
        July.append(i)
    elif (i=='08'):
        August.append(i)
    elif (i=='09'):
        September.append(i)
    elif (i=='10'):
        October.append(i)
    elif (i=='11'):
        November.append(i)
    elif (i=='12'):
        December.append(i)

# %%
January

# %%
#old

# %% [markdown]
# * Copied relevant columns.

# %%
x = ["State", "Deaths", "Year"]
df_data_needed = healthStatus_df[x].copy()

# %% [markdown]
# * Filtered data for certain years
# * Grouped data by state
# * Calculated the number of deaths in 2010.
# * Reset index for dataframe

# %%
df_data_needed_2010=df_data_needed.loc[df_data_needed['Year'] ==2010]
df_data_grouped_2010=df_data_needed_2010.groupby(df_data_needed_2010['State'])
Number_mortality_df_2010=pd.DataFrame({"Deaths_in_2010":df_data_grouped_2010["Deaths"].sum()})
Number_mortality_df_2010=Number_mortality_df_2010.reset_index()

# %% [markdown]
# * Removed unnecessary rows
# * Reset, drop index

# %%
Number_mortality_df_2010=Number_mortality_df_2010[( Number_mortality_df_2010.State!='United States')]

Number_mortality_df_2010= Number_mortality_df_2010.reset_index(drop=True)
Number_mortality_df_2010.head()

# %% [markdown]
# * Filtered data for certain years
# * Grouped data by state
# * Calculated the number of deaths in 2015.
# * Reset index for dataframe

# %%
df_data_needed_2015=df_data_needed.loc[df_data_needed['Year'] ==2015]
df_data_grouped_2015=df_data_needed_2015.groupby(df_data_needed_2015['State'])
Number_mortality_df_2015=pd.DataFrame({"Deaths_in_2015":df_data_grouped_2015["Deaths"].sum()})
Number_mortality_df_2015=Number_mortality_df_2015.reset_index()

# %% [markdown]
# * Removed unnecessary rows
# * Reset, drop index

# %%
Number_mortality_df_2015=Number_mortality_df_2015[( Number_mortality_df_2015.State!='United States')]
Number_mortality_df_2015= Number_mortality_df_2015.reset_index(drop=True)

Number_mortality_df_2015.head()

# %% [markdown]
# * Loaded file
# * Readed file and stored into Pandas data frame

# %%
file_to_load2 = "states.csv"

insurance_df = pd.read_csv(file_to_load2, delimiter=',', encoding="utf-8", dtype={'Time Occurred':str})

insurance_df.head()

# %% [markdown]
# * Copied relevant columns.

# %%
y = ["State", "Uninsured Rate (2010)", "Uninsured Rate (2015)"]
needed_insurance_df= insurance_df[y].copy()
needed_insurance_df.head()

# %% [markdown]
# * Removed unnecessary rows

# %%
needed_insurance_df=needed_insurance_df[(needed_insurance_df.State!='United States')]
needed_insurance_df.head()

# %%
file_to_load3 = "Population.csv"

population_df = pd.read_csv(file_to_load3, delimiter=',', encoding="utf-8", dtype={'Time Occurred':str})
population_df.head()

# %%
# population_df=population_df[(needed_insurance_df.State!='United States')]
# population_df=population_df.drop('Unnamed:1', axis=1)

# %% [markdown]
# * Cleaned whitespaces and made lowercase "State" column

# %%
Number_mortality_df_2015["State"] = Number_mortality_df_2015["State"].apply(lambda x : x.lower().strip())
needed_insurance_df["State"] = needed_insurance_df["State"].apply(lambda x : x.lower().strip())
Number_mortality_df_2010["State"] = Number_mortality_df_2010["State"].apply(lambda x : x.lower().strip())
population_df["State"]=population_df["State"].apply(lambda x : x.lower().strip())

# %% [markdown]
# * Joined dataframes

# %%
merged_df_one = pd.merge( Number_mortality_df_2015, needed_insurance_df, on="State", how='left')
merged_df_one.head()

# %%
merged_df_two=pd.merge(population_df, merged_df_one, on="State", how='left')
merged_df_two.head()

# %% [markdown]
# * Joined dataframes
# * Changed names of columns of final dataframe

# %%
merged_df_final = pd.merge(Number_mortality_df_2010, merged_df_two, on="State", how='left')

merged_df_final = merged_df_final.rename(columns={"State": "State",
                                      "Deaths_in_2010": "Deaths_in_2010",
                                       "Population_Year_2010" :"Population_Year_2010",
                                      "Population_Year_2015":"Population_Year_2015",
                                      "Deaths_in_2015": "Deaths_in_2015",
                                      "Uninsured Rate (2010)": "Uninsured_Rate_2010",
                                      "Uninsured Rate (2015)": "Uninsured_Rate_2015"})
merged_df_final["Uninsured_Rate_2010"] = merged_df_final["Uninsured_Rate_2010"].astype('').dtypes
merged_df_final.head()

# %% [markdown]
# * Stored dataframe to a SQL database.

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://test:test@localhost:5432/ETL_project", echo=False)

merged_df_final.to_sql("Number_mortality", con=engine,index=False, if_exists="replace")
